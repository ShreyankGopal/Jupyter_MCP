# %%
base_value=10
print("hi")
# Out:
# hi

# %%
# Cell 2: Process data from Cell 1
processed_value = base_value * 2
squared_numbers = [x ** 2 for x in numbers]
print(f"Processed: {processed_value}, Squared: {squared_numbers}")

# %%
# Cell 3: Create summary using data from Cell 2
total = sum(squared_numbers)
result_string = f"{name}: total={total}, base={base_value}"
print(result_string)

# %%
# Cell 4: Final analysis using results from Cell 3
average = total / len(squared_numbers)
final_report = f"Average={average:.2f}, {result_string}"
print(final_report)

# %%
# Cell 1: Base data definitions
base_value = 10
numbers = [1, 2, 3, 4, 5]
name = "data_processing"
print(f"Base setup complete: {base_value}, {numbers}, {name}")
# Out:
# Base setup complete: 10, [1, 2, 3, 4, 5], data_processing
